# %%
import CRAWLING
import ANALYSIS
import API
import os
from dotenv import load_dotenv
from tqdm import tqdm
import json
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 0
# ### 데이터 가공

# %%
ORDER = {0: 'First', 1: 'Second', 2: 'Third', 3: 'Total'}

# %%
def idGroup():
    ids = {0: [], 5:[], 10:[]}

    for minute in [0, 5, 10]:
        path = f'./Data/{minute}m break/'
        filelist = os.listdir(path)
        ids[minute] = list(set([int(file[:2]) for file in filelist]))
        
    return ids

# %%
def DataParser(minute):
    path = f'./Data/{minute}m break/'
    filelist = os.listdir(path)
    ids = set([file[:2] for file in filelist])
    group = {}

    for idx in ids:
        data = []
        for i in range(3):
            data.append(pd.read_csv(f'./Data/{minute}m break/{idx}_{i+1}.csv', index_col=0).T.reset_index())
            data[i]['index'] = data[i]['index'].astype(int)
            data[i]['class'] = data[i]['class'].astype(int)
            data[i]['speed'] = data[i]['speed'].astype(float)
            data[i]['text'] = data[i]['text']
            data[i]['color'] = data[i]['color'].apply(lambda x: list(map(int, x.strip('()').split(', '))))
        data.append(data[0])
        data[3] = pd.concat([data[3], data[1], data[2]], axis=0, ignore_index=True)
        data[3] = data[3].iloc[:, 1:].reset_index()
        group[idx] = data
    
    return group

# %%
Group = {}
for i in [0, 5, 10]:
    Group[i] = DataParser(i)

# %%
Group[0]['12']
# Out:
# [     index  class     speed  text          color
#  0        0      1  2.273916    파랑    [0, 0, 255]
#  1        1      1  2.163251  XXXX  [255, 255, 0]
#  2        2      1  0.647575    파랑  [255, 255, 0]
#  3        3      1  1.137837  XXXX    [0, 0, 255]
#  4        4      1  0.922457    파랑  [255, 255, 0]
#  ..     ...    ...       ...   ...            ...
#  593    593      1  0.436733  XXXX    [0, 0, 255]
#  594    594      1  0.457892    빨강    [0, 0, 255]
#  595    595      1  0.534850  XXXX    [0, 255, 0]
#  596    596      1  0.746140    빨강  [255, 255, 0]
#  597    597      1  0.525037  XXXX    [0, 255, 0]
#
#  [598 rows x 5 columns],
#       index  class     speed  text          color
#  0        0      1  0.179603    파랑    [0, 0, 255]
#  1        1      1  0.580637  XXXX    [0, 255, 0]
#  2        2      1  0.513265    노랑    [0, 255, 0]
#  3        3      1  0.691939  XXXX    [0, 0, 255]
#  4        4      1  1.021549    노랑  [255, 255, 0]
# ...

# %% [markdown]
# # 1
# ### 전체 데이터에 대한 반응속도 추세선의 기울기 간의 상대 점수

# %% [markdown]
# #### a. 전체에 대해

# %%
def all_gradient_z_score():
    gradient = {}
    for g in Group.values():
        for k, p in g.items():
            speed = p[3]['speed']
    
            x = np.arange(len(speed))
            y = speed
    
            coeffs = np.polyfit(x, y, 1)

            slope = coeffs[0]
            gradient[k] = slope
    gradient_np = np.array(list(gradient.values()))

    mean_slope = np.mean(gradient_np)
    std_slope = np.std(gradient_np)
    z_score = (gradient_np - mean_slope) / std_slope
    
    zperid = {}
    for idx, score in zip(gradient.keys(), z_score):
        zperid[idx] = round(score, 3)

    sorted_zscore = {k:v for k, v in sorted(zperid.items())}

    df = pd.DataFrame(list(sorted_zscore.items()), columns = ['id', 'z_score'])
    df['rank'] = df['z_score'].rank(ascending=False, method='min').astype(int)
    df.set_index('id', inplace=True)
    df.to_excel('./Graphs/z_score_all.xlsx')
    return df

# %%
all_gradient_z_score()
# Out:
#     z_score  rank
# id
# 01    0.159    12
# 02    0.813     6
# 03    0.660     7
# 04    1.352     2
# 05   -0.503    20
# 06    1.118     4
# 07   -2.049    28
# 08   -0.224    16
# 09    0.300    11
# 10   -1.984    27
# 11   -0.619    21
# 12    2.711     1
# 13   -0.631    23
# 14   -0.471    19
# 15   -1.176    26
# 16    0.432     9
# 17   -0.307    17
# 18   -0.045    14
# 19    0.629     8
# 20   -0.951    25
# 22    1.104     5
# 23    0.035    13
# 25    0.323    10
# 26   -0.625    22
# 27   -0.216    15
# 28    1.250     3
# 29   -0.688    24
# 30   -0.398    18

# %% [markdown]
# #### b. 그룹 별

# %%
def Group_gradient_z_score():
    for m, g in Group.items():
        gradient = {}
        for k, p in g.items():
            speed = p[3]['speed']
    
            x = np.arange(len(speed))
            y = speed
    
            coeffs = np.polyfit(x, y, 1)

            slope = coeffs[0]
            gradient[k] = slope
        gradient_np = np.array(list(gradient.values()))
    
        mean_slope = np.mean(gradient_np)
        std_slope = np.std(gradient_np)
        z_score = (gradient_np - mean_slope) / std_slope
        
        zperid = {}
        for idx, score in zip(gradient.keys(), z_score):
            zperid[idx] = round(score, 3)
    
        sorted_zscore = {k:v for k, v in sorted(zperid.items())}
    
        df = pd.DataFrame(list(sorted_zscore.items()), columns = ['id', 'z_score'])
        df['rank'] = df['z_score'].rank(ascending=False, method='min').astype(int)
        df.set_index('id', inplace=True)
        df.to_excel(f'./Graphs/z_score_group_{m}.xlsx')

# %%
Group_gradient_z_score()

# %% [markdown]
# # 2
# ### 그룹 3개에 대한 블록 3개의 데이터 표
# 평균, 분산

# %%
speed = {}
for m, g in Group.items():
    speed[m] = {'block 1': [], 'block 2': [], 'block 3': []}
    for k, p in g.items():
        for i in range(3):
            speed[m][f'block {i+1}'].append(p[i]['speed'])

data_m = {0:[], 5:[], 10:[]}
data_v = {0:[], 5:[], 10:[]}
for m, g in speed.items():
    for block, lists in g.items():
        block_all = []
        for p in lists:
            for s in p:
                block_all.append(s)
        mean = np.mean(block_all)
        var = np.var(block_all)

        data_m[m].append(mean)
        data_v[m].append(var)

# %%
df_m = pd.DataFrame(data_m)
df_m.index=['Block 1', 'Block 2', 'Block 3']
df_m.to_excel('./Graphs/Mean_of_data.xlsx')
df_m
# Out:
#                0         5         10
# Block 1  0.775976  0.670519  0.880121
# Block 2  0.795824  0.632092  0.858837
# Block 3  0.873295  0.641781  0.912771

# %%
df_v = pd.DataFrame(data_v)
df_v.index=['Block 1', 'Block 2', 'Block 3']
df_v.to_excel('./Graphs/Varience_of_data.xlsx')
df_v
# Out:
#                0         5         10
# Block 1  0.157558  0.143865  0.332692
# Block 2  0.149964  0.079481  0.279438
# Block 3  0.205515  0.082976  0.274244

# %% [markdown]
# # 3
# ### scatter plot

# %%
def draw_plot():
    for g in Group.values():
        for k, p in g.items():
            speed = p[3]['speed']
    
            x = np.arange(len(speed))
            y = speed
    
            coeffs = np.polyfit(x, y, 1)
            poly = np.poly1d(coeffs)

            slope = coeffs[0]

            plt.scatter(x, y, alpha=0.7, s = 2)

            plt.plot(x, poly(x), linestyle='-', c = 'orange')

            plt.xlabel("Time")
            plt.ylabel("Speed")
            plt.title(f"{k} Speed Graph")

            plt.text(0.7 * max(x), 0.9 * max(y), f"Slope: {slope:.6f}", fontsize=10, color='red')
            
            plt.savefig(f"./Graphs/All/{k}.png")

            plt.clf()

# %%
draw_plot()

# %% [markdown]
# # 4
# ### 개인의 승률 크롤링 데이터로 연속 게임 승률 / 분당 골드 변화

# %% [markdown]
# #### ID/Tagline/Group DataFrame

# %%
subject = pd.read_excel('./Data/id_tag.xlsx')
subject.rename(columns={'태그': 'Tagline'}, inplace=True)
subject['gameName'] = None
for _, row in subject.iterrows():
    try:
        subject.loc[subject['ID']==row['ID'], ['gameName']] = row['Tagline'].split('#')[0]
        subject.loc[subject['ID']==row['ID'], ['Tagline']] = row['Tagline'].split('#')[1]
    except:
        continue
        
subject['Group'] = 0
subject['Result'] = None

# %%
group = idGroup()
for t, g in group.items():
    for i in g:
        subject.loc[subject['ID'] == i, 'Group'] = t

# %%
subject.loc[subject['Tagline'] == '(검색 x)', 'Result'] = 'Can\'t Find'
subject.loc[subject['Tagline'] == '(중국)', 'Result'] = 'Can\'t Find'

# %%
subject
# Out:
#     ID Tagline     gameName  Group      Result
# 0    1  (검색 x)       (검색 x)      0  Can't Find
# 1    2     0 5   last dance      0        None
# 2    3  (검색 x)       (검색 x)     10  Can't Find
# 3    4    used       Snooze     10        None
# 4    5     KR1      Flpelch      5        None
# 5    6  (검색 x)       (검색 x)      5  Can't Find
# 6    7  (검색 x)       (검색 x)      5  Can't Find
# 7    8     KR1          하준상      0        None
# 8    9     KR1   Hard Rain1      5        None
# 9   10     y e          김맨부     10        None
# 10  11    8503          콩직이     10        None
# 11  12    QV30     NewJeans      0        None
# 12  13     KR1        딴따라고기      5        None
# 13  14     KR1    초신성 괴물 원딜      5        None
# 14  15    (중국)         (중국)     10  Can't Find
# 15  16     양성소       리틀 프린스      0        None
# 16  17  (검색 x)       (검색 x)      0  Can't Find
# 17  18     KR1     졸부가되고싶어요     10        None
# 18  19     KR1        홍삼맛쿠키     10        None
# ...

# %% [markdown]
# #### 10분 간격 5게임 승률/분당골드

# %% [markdown]
# Data Crawling

# %%
def analysis_one(ID, count, time_term, result):
    try:
        gamecount = ANALYSIS.consecutive_game_by(s['ID'], count, time_term)
        ANALYSIS.draw_winrate(s['ID'], count, time_term)
        ANALYSIS.draw_cpm(s['ID'], count, time_term)
        ANALYSIS.draw_gpm(s['ID'], count, time_term)
        result[s['ID']] = gamecount
        if gamecount == 0:
            result[s['ID']] = 'NO DATA'
    except:
        result[s['ID']] = 'NO DATA'
    return result

# %%
result = {}
for _, s in subject.iterrows():
    if s['Result'] != None:
        continue
    data = CRAWLING.ID_to_data(s['gameName'], s['Tagline'], 50)
    if data.empty:
        result[s['ID']] = 'NO ID'
        continue
    data.to_csv(f'./Data/Subject Crawl/{s['ID']}.csv')
    
    analysis_one(s['ID'], 5, 10, result)
# Out:
# Crawling [last dance] #0 5:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 2: number of data = 3
# Crawling [Snooze] #used:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 4: number of data = 3
# Crawling [Flpelch] #KR1:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 5: number of data = 0
# Crawling [하준상] #KR1:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 8: number of data = 39
# Crawling [Hard Rain1] #KR1:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 9: number of data = 54
# Crawling [김맨부] #y e:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 10: number of data = 31
# Crawling [콩직이] #8503:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 11: number of data = 7
# Crawling [NewJeans] #QV30:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 12: number of data = 10
# Crawling [딴따라고기] #KR1:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 13: number of data = 16
# Crawling [초신성 괴물 원딜] #KR1:   0%|          | 0/50 [00:00<?, ?it/s]
# ID 14: number of data = 20
# ...

# %%
for r in result.keys():
    subject.loc[subject['ID'] == r, 'Result'] = result[r]

# %%
subject.to_excel('./Data/Result.xlsx')

# %%
subject
# Out:
#     ID Tagline     gameName  Group      Result
# 0    1  (검색 x)       (검색 x)      0  Can't Find
# 1    2     0 5   last dance      0           3
# 2    3  (검색 x)       (검색 x)     10  Can't Find
# 3    4    used       Snooze     10           3
# 4    5     KR1      Flpelch      5     NO DATA
# 5    6  (검색 x)       (검색 x)      5  Can't Find
# 6    7  (검색 x)       (검색 x)      5  Can't Find
# 7    8     KR1          하준상      0          39
# 8    9     KR1   Hard Rain1      5          54
# 9   10     y e          김맨부     10          31
# 10  11    8503          콩직이     10           7
# 11  12    QV30     NewJeans      0          10
# 12  13     KR1        딴따라고기      5          16
# 13  14     KR1    초신성 괴물 원딜      5          20
# 14  15    (중국)         (중국)     10  Can't Find
# 15  16     양성소       리틀 프린스      0          21
# 16  17  (검색 x)       (검색 x)      0  Can't Find
# 17  18     KR1     졸부가되고싶어요     10           3
# 18  19     KR1        홍삼맛쿠키     10           1
# ...

# %% [markdown]
# # 5
# ### 색깔이 같을 때와 다를 때의 반응속도 차이 (그룹별)

# %% [markdown]
# #### color text를 list로 변환

# %%
def colors(color):
    rgb = []
    if color == '빨강':
        rgb = [255, 0, 0]
    elif color == '초록':
        rgb = [0, 255, 0]
    elif color == '파랑':
        rgb = [0, 0, 255]
    elif color == '노랑':
        rgb = [255, 255, 0]
    return rgb

# %% [markdown]
# #### 1. congurent 여부에 따른 반응속도 분포와 평균
# Neutral/Congruent/Incongruent

# %%
speed_by_color = {'congruent': [], 'incongruent': [], 'neutral': []}
for m, g in Group.items():
    for k, p in g.items():
        df = pd.DataFrame(p[3])
        speed_by_color['neutral'].extend(df.loc[df['text'] == 'XXXX', 'speed'].to_list())
        speed_by_color['congruent'].extend(df.loc[df['text'].apply(colors) == df['color'], 'speed'].to_list())
        speed_by_color['incongruent'].extend(df.loc[(df['text'].apply(colors) != df['color']) & (df['text'] != 'XXXX'), 'speed'].to_list())

# %%
max_length = max(len(values) for values in speed_by_color.values())

for key, values in speed_by_color.items():
    while len(values) < max_length:
        values.append(np.nan)

df = pd.DataFrame(speed_by_color)

df_melted = df.melt(var_name='Condition', value_name='Speed')

plt.figure(figsize=(8, 6))

ax = sns.boxplot(x='Condition', y='Speed', data=df_melted, 
                 hue='Condition',         # 'Condition'을 hue로 설정
                 palette='Set2',          # 색상 팔레트 지정
                 width=0.4)               # 수염 그래프 너비 조정

for condition in df_melted['Condition'].unique():
    mean_value = df_melted[df_melted['Condition'] == condition]['Speed'].mean()

    ax.text(x=df_melted['Condition'].unique().tolist().index(condition), 
            y=mean_value + 0.13,  
            s=f'Mean: {mean_value:.2f}',  
            ha='center',  
            fontsize=12,   
            color='black') 

plt.title('Reaction time by Condition')
plt.xlabel('Condition')
plt.ylabel('Time taken')

plt.savefig(f"./Graphs/Boxplot_Speed_by_Condition.png")

plt.show()

# %% [markdown]
# #### 2. Congruent 여부에 따른 데이터 (요청)

# %%
speed_by_color = {'congruent': [], 'incongruent': [], 'neutral': []}
for m, g in Group.items():
    for k, p in g.items():
        df = pd.DataFrame(p[3])
        speed_by_color['neutral'].extend(df.loc[df['text'] == 'XXXX', 'speed'].to_list())
        speed_by_color['congruent'].extend(df.loc[df['text'].apply(colors) == df['color'], 'speed'].to_list())
        speed_by_color['incongruent'].extend(df.loc[(df['text'].apply(colors) != df['color']) & (df['text'] != 'XXXX'), 'speed'].to_list())

# %%
for m, g in Group.items():
    for k, p in g.items():
        playerdf = pd.DataFrame({'index': [i for i in range(1, 601)]})
        for i in range(3):
            df = pd.DataFrame(p[i]).iloc[:,1:]
            df['new'] = df.apply(lambda row: 'N' if row['text'] == 'XXXX' else ('C' if colors(row['text']) == row['color'] else 'I'),
                                      axis=1)
            df = df.loc[:,['class', 'speed', 'new']]
            df.rename(columns={'class':f'Block{i+1}_class', 'speed':f'Block{i+1}_speed', 'new':f'Block{i+1}_congruent'}, inplace=True)
            playerdf = pd.concat([playerdf, df], axis=1)
        playerdf.T.to_excel(f'./Data/Subject Data/Group_{m} ID_{k}.xlsx', index=True)

# %% [markdown]
# # 6
# ### 평균 반응속도/정확도 (그룹별)

# %% [markdown]
# #### 평균 반응속도

# %%
speed = {}
for m, g in Group.items():
    speed[m] = {'block 1': [], 'block 2': [], 'block 3': []}
    for k, p in g.items():
        for i in range(3):
            speed[m][f'block {i+1}'].append(p[i]['speed'])

data_m = {0:[], 5:[], 10:[]}
data_v = {0:[], 5:[], 10:[]}
for m, g in speed.items():
    for block, lists in g.items():
        block_all = []
        for p in lists:
            for s in p:
                block_all.append(s)
        mean = np.mean(block_all)
        var = np.var(block_all)

        data_m[m].append(mean)
        data_v[m].append(var)

# %%
df_m = pd.DataFrame(data_m)
df_m.index=['Block 1', 'Block 2', 'Block 3']
df_m.to_excel('./Graphs/Mean_of_speed.xlsx')
mean_by_group = df_m.mean()

# %%
mean_by_group
# Out:
# 0     0.815032
# 5     0.648131
# 10    0.883910
# dtype: float64

# %% [markdown]
# #### 평균 정확도

# %%
accuracy = {}
for m, g in Group.items():
    accuracy[m] = {'block 1': [], 'block 2': [], 'block 3': []}
    for k, p in g.items():
        for i in range(3):
            accuracy[m][f'block {i+1}'].append(p[i]['class'])
data_m = {0:[], 5:[], 10:[]}
for m, g in accuracy.items():
    for block, lists in g.items():
        block_all = []
        for p in lists:
            for s in p:
                block_all.append(s)
        mean = np.mean(block_all)

        data_m[m].append(mean)

# %%
df_m = pd.DataFrame(data_m)
df_m.index=['Block 1', 'Block 2', 'Block 3']
df_m.to_excel('./Graphs/Mean_of_accracy.xlsx')
mean_by_group = df_m.mean()

# %%
mean_by_group
# Out:
# 0     0.947607
# 5     0.948199
# 10    0.904418
# dtype: float64

# %% [markdown]
# # 7
# ### 보고서 제작

# %% [markdown]
# #### 1) 언제 게임 할 때 승률이 가장 높은지
# 1. 시작 시간 기준
# 2. 1시간 단위

# %% [markdown]
# > 실험대상: 하준상 #KR1

# %% [markdown]
# ##### import

# %%
import requests as rq
import time
from bs4 import BeautifulSoup as bs
import re
import datetime
import random

# %% [markdown]
# ##### 1년치 데이터 수집

# %%
def ID_to_sid(ID, tag):
    snapshot = rq.get(f"https://www.fow.lol/find/kr/{ID}-{tag}").text
    soup = bs(snapshot, 'html.parser')
    cover = soup.find('div', id='content-container')
    sid_line = str(cover.find('div', "fbtn lv"))

    sid_re = re.compile(r'(data\-sid=\")(\d*)')
    sid = re.findall(sid_re, sid_line)[0][1]
    return sid

# %%
def html(sid, timestamp=int(time.time())):
    return rq.get(f'https://www.fow.lol/api/gamesmore?region=kr&sid={sid}&ts={timestamp}&type=solo&champ=0').text

# %%
def parsing(text):
    games_re = re.compile(r'<div class=\"gameDetail hidden\" data-game-id="\d*">\r\n</div>')
    games = re.split(games_re, text)

    return games

# %%
def next_timestamp(crawl_list):
    return int(re.findall(r'\d+', crawl_list)[0])

# %%
def timestringTotimestamp(time_string):
    element = re.findall(r'\d+', time_string)
    t = int(element[3])
    if re.findall(r'후', time_string):
        if t == 12:
            clock = element[3]
        else:
            clock = f'{int(element[3]) + 12}'
    else:
        if t == 12:
            clock = f'{int(element[3]) - 12}'
        else:
            clock = element[3]
    reorganize = element[0] + '-' + element[1] + '-' + element[2] + ' ' + clock + ':' + element[4] + ':' + element[5]
    return datetime.datetime.strptime(reorganize, '%Y-%m-%d %H:%M:%S').timestamp()

# %%
def crawl_to_dict(game):
    soup = bs(game, 'html.parser')
    dict = {}

    dict['win'] = soup.find('div')['class'][1]
    timeinfo = soup.find_all('div')[-4]
    time = re.findall(r'\d+\. \d+\. \d+\. 오[전|후] \d+:\d+:\d+', timeinfo.find_all('span', 'tipsy_live')[0]['tipsy'])
    dict['start'] = int(timestringTotimestamp(time[0]))
    dict['end'] = int(timestringTotimestamp(time[1]))

    return dict

# %%
def ID_to_data(ID, tag):
    try:
        sid = ID_to_sid(ID, tag)
    except:
        return pd.DataFrame()
    game_info = pd.DataFrame()

    order = True
    total_games = 100
    with tqdm(total=total_games, desc='Crawling FOW.gg', ncols = 0) as pbar:
        while True:
            if order:
                data = html(sid)
                order = False
            elif (not order) & (next_page_ts == None):
                break
            else:
                time.sleep(random.uniform(0.5, 1))
                data = html(sid, next_page_ts)
            plist = parsing(data)
    
            for game in plist[0:-1]:
                try:
                    dict = crawl_to_dict(game)
                except:
                    continue
                df = pd.DataFrame(dict, index=[0])
                df_cleaned = df.dropna(axis=1, how='any')
                if game_info.empty:
                    game_info = df
                else:
                    try:
                        game_info = pd.concat([game_info, df_cleaned], axis=0, ignore_index=True)
                    except:
                        pass
            #print(game_info)
            #print(game_info.iloc[0]['start'] - game_info.iloc[-1]['start'])
            #count += 1
            #if count == 5: break

            last_time = pd.to_datetime(game_info.iloc[-1]['start'], unit='s')
            formatted_time = last_time.strftime('%Y-%m')
            pbar.update(1)
            pbar.set_postfix({'Last Added': formatted_time})
            
            if game_info.iloc[0]['start'] - game_info.iloc[-1]['start'] > 31556926:
                break
            try:
                next_page_ts = next_timestamp(plist[-1])
            except:
                next_page_ts = None

    return game_info

# %% [markdown]
# ##### 기간별 승률

# %%
def period_winrate(sample, ID, Tagline):    
    pd.set_option("future.no_silent_downcasting", True)
    
    sample.replace({'win': 1, 'loss': 0, 'draw':None}, inplace=True)
    sample['start'] = pd.to_datetime(sample['start'], unit='s')
    sample['hour_range'] = sample['start'].dt.hour.astype(str) + '시~' + (sample['start'].dt.hour + 1).astype(str) + '시'
    result = sample.groupby('hour_range').agg(
        win_rate=('win', 'mean'),  # win의 평균
        count = ('win', 'size')  # win의 개수
        ).reset_index()
    
    result['hour_start'] = result['hour_range'].str.extract(r'(\d+)').astype(int)  # 숫자만 추출하여 정렬
    result = result.sort_values('hour_start').drop('hour_start', axis=1).reset_index(drop=True)

    plt.rcParams['font.family'] = 'Malgun Gothic'
    fig, ax1 = plt.subplots(1, 1, figsize = (12, 4))
    
    ax1.plot(result['hour_range'], result['win_rate'], color = 'salmon')
    ax1.set_xlabel('시간대')
    ax1.set_ylabel('승률', color = 'orangered')
    ax1.tick_params(axis='y', labelcolor='orangered')
    
    ax2 = ax1.twinx()
    ax2.bar(result['hour_range'], result['count'], color = 'skyblue', alpha = 0.4)
    ax2.set_ylabel('횟수', color = 'royalblue')
    ax2.tick_params(axis='y', labelcolor='royalblue')
    
    ax1.set_xticks(result['hour_range'])
    ax1.set_xticklabels(result['hour_range'], rotation=45, ha='right')  # 45도 기울이고, 오른쪽 정렬
    
    ax1.set_zorder(2)
    ax1.patch.set_visible(False)
    ax1.set_title('게임 시작 시간에 따른 승률')


    plt.subplots_adjust(bottom=0.2)
    plt.savefig(f'./Graphs/Report_image/period_winrate_{ID}#{Tagline}.png', bbox_inches='tight')
    
    plt.show()

# %% [markdown]
# #### 2) 개인의 게임 간 휴식시간 별 다음 게임의 승률
# 1. 0 ~ 5 / 5 ~ 10 / 10 ~ 15 / 15 ~ 60 / 60 ~
# 2. “당신은 몇 분 이상 휴식할 때 승률이 좋습니다.”

# %%
def breaktime_winrate(sample, ID, Tagline):
    pd.set_option("future.no_silent_downcasting", True)

    sample.replace({'win': 1, 'loss': 0, 'draw':None}, inplace=True)

    sample['start'] = pd.to_datetime(sample['start'], unit = 's')
    sample['end'] = pd.to_datetime(sample['end'], unit = 's').shift(-1)

    sample['time_gap'] = sample['start'] - sample['end']
    sample['time_gap'] = sample['time_gap'].dt.total_seconds() / 60
    sample['time_gap'] = sample['time_gap'].fillna(0)
    
    bins = [0, 5, 10, 15, 60, float('inf')]  # 0-5분, 5-10분, 10-15분, 15-60분, 60분 이상
    labels = ['0~5 분', '5~10 분', '10~15분', '15~60 분', '60분 이상']
    sample['time_range'] = pd.cut(sample['time_gap'], bins=bins, labels=labels, right=False)
    
    # 3. 각 구간별 개수와 승률 계산 (빈 구간에도 0으로 설정)
    grouped = sample.groupby('time_range', observed=True).agg(
        count=('win', 'size'),  # 각 구간의 데이터 개수
        win_rate=('win', 'mean')  # 각 구간의 승률
    ).reset_index()
    
    # 빈 구간에 대해 count와 win_rate를 0으로 설정
    full_range = pd.DataFrame({
        'time_range': labels,
        'count': [0] * len(labels),
        'win_rate': [0.0] * len(labels)
    })

    result = pd.merge(full_range, grouped, on='time_range', how='left', suffixes=('_filled', ''))
    result['count'] = result['count'].fillna(result['count_filled'])
    result['win_rate'] = result['win_rate'].fillna(result['win_rate_filled'])
    result.drop(['count_filled', 'win_rate_filled'], axis=1, inplace=True)

    plt.rcParams['font.family'] = 'Malgun Gothic'
    fig, ax1 = plt.subplots(1, 1, figsize = (6, 4))
    
    ax1.plot(result['time_range'], result['win_rate'], color = 'salmon')
    ax1.set_xlabel('휴식시간')
    ax1.set_ylabel('승률', color = 'orangered')
    ax1.tick_params(axis='y', labelcolor='orangered')
    
    ax2 = ax1.twinx()
    ax2.bar(result['time_range'], result['count'], color = 'skyblue', alpha = 0.4)
    ax2.set_ylabel('횟수', color = 'royalblue')
    ax2.tick_params(axis='y', labelcolor='royalblue')
    
    ax1.set_xticks(result['time_range'])
    ax1.set_xticklabels(result['time_range'], rotation=45, ha='right')  # 45도 기울이고, 오른쪽 정렬
    
    ax1.set_zorder(2)
    ax1.patch.set_visible(False)
    ax1.set_title('휴식시간에 따른 승률')

    plt.subplots_adjust(bottom=0.2)
    plt.savefig(f'./Graphs/Report_image/breaktime_winrate_{ID}#{Tagline}.png', bbox_inches='tight')
    
    plt.show()

# %% [markdown]
# #### 3) timeline data -> 분당 골드 획득 변동
# 1. 선그래프
# 2. 4개 연속을 그냥 좌우 concat
# 3. concat한 지점 표시(수직선)
# 4. 4게임이 안 나오는 사람은 수를 줄여서

# %% [markdown]
# ##### .env 보안파일 열기

# %%
load_dotenv()
KEY = os.environ.get('RIOT_API_KEY')

# %% [markdown]
# ##### timeline data 수집

# %%
def collect_timelinedata(ID, Tagline):
    puuid = API.gameNameTopuuid(ID, Tagline, KEY)['puuid']
    matchids = API.puuidTomatchId(puuid, KEY)
    
    pbar = tqdm(matchids,
               total = len(matchids),
               desc = 'Turnning Match ID to Match Data',
               ncols = 100,
               leave = True)

    gold_per_time_data = []
    for matchid in pbar:
        data = API.timeline(matchid, KEY)['info']
        playerid = 0
        for participant in data['participants']:
            if participant['puuid'] == puuid:
                playerid = participant['participantId']
        if playerid == 0:
            print('Can\'t find puuid')
            continue

        frames = data['frames']
        gameinfodict = {'start':0, 'end':0, 'gold_flow':[], 'cs_flow':[]}
        
        try:
            gameinfodict['start'] = [event['realTimestamp'] for event in frames[0]['events'] if event['type'] == 'PAUSE_END'][0]
            gameinfodict['end'] = [event['realTimestamp'] for event in frames[-1]['events'] if event['type'] == 'GAME_END'][0]
        except Exception as e:
            print(e)
            continue

        try:
            previous_gold = 500
            previous_cs = 0
            for frame in frames:
                current_gold = frame['participantFrames'][f'{playerid}']['totalGold']
                current_cs = frame['participantFrames'][f'{playerid}']['jungleMinionsKilled'] + frame['participantFrames'][f'{playerid}']['minionsKilled']
                
                gameinfodict['gold_flow'].append(current_gold-previous_gold)
                gameinfodict['cs_flow'].append(current_cs-previous_cs)
            
                previous_gold = current_gold
                previous_cs = current_cs
        except Exception as e:
            print(e)
            continue
        gold_per_time_data.append(gameinfodict)
    return gold_per_time_data

# %% [markdown]
# ##### 데이터 가공

# %%
def consecutive_goldcs(ID, Tagline):
    data = collect_timelinedata(ID, Tagline)
    
    consecutives = []

    games = len(data)
    temp = []
    on = True
    for game in reversed(range(1, games)):
        if game == games-1:
            temp.append(data[game])
        else:
            if (data[game]['start'] - data[game+1]['end']) > 600000:
                temp = []
                if on:
                    on = False
            
            temp.append(data[game])
        
        if len(temp) == 4:
            if on:
                on = False
                continue
            consecutives.append(temp[:4])
    
    return consecutives

# %% [markdown]
# ##### 시각화

# %% [markdown]
# 추세선(선형회귀선) 함수

# %%
def add_trendline(ax, df):
    x = np.arange(len(df))  # x축 값
    y = df.T.mean().values  # y축 값 (평균 값)
    
    # NaN 값이 있는 부분은 제외하고 계산
    mask = ~np.isnan(y)
    x_clean = x[mask]
    y_clean = y[mask]
    
    # 선형 회귀로 추세선 계산
    coef = np.polyfit(x_clean, y_clean, 1)  # 1은 선형 (차수)
    trendline = np.polyval(coef, x_clean)  # 추세선 계산
    
    # 추세선 추가
    ax.plot(x_clean, trendline, color='darkred', linestyle='-.', label='Trendline')

    slope = coef[0]
    ax.text(0.9, 0.1, f"Slope: {slope:.4f}", transform=ax.transAxes, color='red', fontsize=12, ha='right')

# %% [markdown]
# Concat -> Mean

# %%
def visualization1(ID, Tagline):
    data = consecutive_goldcs(ID, Tagline)

    count = 1
    gold_all = {}
    cs_all = {}
    for games in data:
        gold = []
        cs = []
        for game in games:
            gold.extend(game['gold_flow'])
            cs.extend(game['cs_flow'])
        gold_all[count] = gold
        cs_all[count] = cs
        count += 1

    # 최대 길이를 구함
    max_length_gold = max(len(v) for v in gold_all.values())
    max_length_cs = max(len(v) for v in cs_all.values())
    
    # gold_all의 리스트 길이를 맞추기
    for key, value in gold_all.items():
        if len(value) < max_length_gold:
            gold_all[key] = value + [np.nan] * (max_length_gold - len(value))
    
    # cs_all의 리스트 길이를 맞추기
    for key, value in cs_all.items():
        if len(value) < max_length_cs:
            cs_all[key] = value + [np.nan] * (max_length_cs - len(value))
        
    gold_df = pd.DataFrame(gold_all)
    cs_df = pd.DataFrame(cs_all)

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    
    ax1.plot(gold_df.T.mean(), color='yellowgreen')
    ax2.plot(cs_df.T.mean(), color='yellowgreen')

    add_trendline(ax1, gold_df)
    add_trendline(ax2, cs_df)
    
    ax1.set_title('골드 수급량')
    ax2.set_title('CS 수급량')
    
    # X-ticks 설정: 10 단위로 설정
    tick_interval = 10  # X-tick 간격
    ax1.set_xticks(np.arange(0, len(gold_df), tick_interval))  # X-ticks 설정
    ax2.set_xticks(np.arange(0, len(cs_df), tick_interval))  # X-ticks 설정
    
    # x-label 표시를 위한 설정 (잘리지 않도록 설정)
    ax1.set_xticklabels(np.arange(0, len(gold_df), tick_interval))  # X-ticks 라벨 설정
    ax2.set_xticklabels(np.arange(0, len(cs_df), tick_interval))  # X-ticks 라벨 설정

    plt.tight_layout()  # 여백 조정
    plt.savefig(f'./Graphs/Report_image/Changes01_{ID}#{Tagline}.png')
    plt.show()

# %% [markdown]
# Mean -> Concat

# %%
def visualization2(ID, Tagline):
    data = consecutive_goldcs(ID, Tagline)
    df = pd.DataFrame(data)
    
    gold_all = {}
    cs_all = {}

    block_end_position_gold = []
    block_end_position_cs = []
    
    for block in df:
        gold_flow = []
        cs_flow = []
        for game in df[block]:
            gold_flow.append(game['gold_flow'])
            cs_flow.append(game['cs_flow'])
        max_gold = max(len(v) for v in gold_flow)
        max_cs = max(len(v) for v in cs_flow)
        for flow in gold_flow:
            if len(flow) < max_gold:
                flow.extend([np.nan]*(max_gold - len(flow)))
        for flow in cs_flow:
            if len(flow) < max_cs:
                flow.extend([np.nan]*(max_cs - len(flow)))
        gold_all[block] = np.nanmean(np.transpose(gold_flow), axis = 1)
        cs_all[block] = np.nanmean(np.transpose(cs_flow), axis = 1)

        block_end_position_gold.append(len(gold_all[block]))
        block_end_position_cs.append(len(cs_all[block]))
        
    gold_concated = []
    cs_concated = []
    for block in gold_all.values():
        gold_concated.extend(block)
    for block in cs_all.values():
        cs_concated.extend(block)

    gold_df = pd.DataFrame(gold_concated)
    cs_df = pd.DataFrame(cs_concated)
        
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    
    ax1.plot(gold_df.T.mean(), color='yellowgreen')
    ax2.plot(cs_df.T.mean(), color='yellowgreen')

    add_trendline(ax1, gold_df)
    add_trendline(ax2, cs_df)
    
    ax1.set_title('골드 수급량')
    ax2.set_title('CS 수급량')
    
    # X-ticks 설정: 10 단위로 설정
    tick_interval = 10  # X-tick 간격
    ax1.set_xticks(np.arange(0, len(gold_df), tick_interval))  # X-ticks 설정
    ax2.set_xticks(np.arange(0, len(cs_df), tick_interval))  # X-ticks 설정
    
    # x-label 표시를 위한 설정 (잘리지 않도록 설정)
    ax1.set_xticklabels(np.arange(0, len(gold_df), tick_interval))  # X-ticks 라벨 설정
    ax2.set_xticklabels(np.arange(0, len(cs_df), tick_interval))  # X-ticks 라벨 설정

    current_position = 0
    for end_pos in block_end_position_gold:
        if current_position == 0: pass
        else:
            ax1.axvline(x=current_position, color='skyblue', linestyle='--', zorder=0)
        current_position += end_pos

    # cs의 블록 끝에 수직선 추가
    current_position = 0
    for end_pos in block_end_position_cs:
        if current_position == 0: pass
        else:
            ax2.axvline(x=current_position, color='skyblue', linestyle='--', zorder=0)
        current_position += end_pos

    plt.tight_layout()  # 여백 조정
    plt.savefig(f'./Graphs/Report_image/Changes02_{ID}#{Tagline}.png')
    plt.show()

# %% [markdown]
# ##### 연습장

# %% [markdown]
# #### 4) 자동화

# %%
def Graphs(ID, Tagline):
    sample = ID_to_data(ID, Tagline)
    period_winrate(sample, ID, Tagline)
    breaktime_winrate(sample, ID, Tagline)
    visualization2(ID, Tagline)

# %%
Graphs('하준상', 'KR1')
# Out:
# rawling FOW.gg:  27% 27/100 [00:24<01:07,  1.09it/s, Last Added=2024-02]
# urnning Match ID to Match Data: 100%|████████████████████████████| 100/100 [02:46<00:00,  1.67s/it]
